# %%
import pandas as pd
import numpy as np

# %%
# Read in datasets
all_reviews = pd.read_csv('test_set.csv')

# %%
# Drop the 'train_test' column
all_reviews = all_reviews.drop('train_test', axis=1)

# %%
# Add attribute columns
#all_reviews['price (y/n)'] = 0
#all_reviews['quality (y/n)'] = 0
all_reviews['sustainability (y/n)'] = 0
#all_reviews['diversity (y/n)'] = 0
#all_reviews['minority-owned (y/n)'] = 0
#all_reviews['social connectedness (y/n)'] = 0

# %%
# Preview Data
all_reviews
# Out:
#                reviewId        asin date_cleaned             username  \
# 0        R18NC04B57B1WM  B09LRY9C88   2022-04-08           Tina Adcox
# 1        R1MPI8QQ1R4QZY  B09LRY9C88   2022-04-08      Amazon Customer
# 2        R31HH2207Z6W8A  B09LRY9C88   2022-04-08               Hydman
# 3        R36RICDJG8MPW1  B09LRY9C88   2022-04-08            M. Fields
# 4        R3BBWMNCFP15OM  B09LRY9C88   2022-04-08       Bama Road Rage
# ...                 ...         ...          ...                  ...
# 1118320  R3V889SFLL9UGW  B005CVXFP4   2023-04-15         Sara leonard
# 1118321  R3DC73CMBHYGN3  B005CVWZD2   2022-10-26              A'me M.
# 1118322  R2W0HZT4NG8GS0  B005CVXFP4   2019-09-19             bobwrong
# 1118323  R3JDFJDBHU6B3W  B06XS3RTB5   2023-04-25               Carmen
# 1118324  R2ZVSDM56VBJMO  B005CVXFP4   2024-04-14  michael mongelluzzo
#
#                                                  title keyword  verified  \
# ...

# %%
# Sample 3,000 random rows
sample_size = 3000

# %%
# Randomly select 1500 rows
sampled_reviews = all_reviews.sample(n=sample_size, random_state=42)

# %%
# Save dataset
sampled_reviews.to_csv('test_set_3K_sample.csv', index=False)
print('Saved as CSV.')
# Out:
# Saved as CSV.
