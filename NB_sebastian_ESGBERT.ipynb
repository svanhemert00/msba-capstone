# %% [markdown]
# # `NB_sebastian_ESGBERT`
# This notebook appends runs `ESGBERT/EnvironmentalBERT-environmental` and `ESGBERT/SocialBERT-social` on the `all_reviews_merged_3000_sample.csv` dataset and appends the results as two new columns.

# %% [markdown]
# ## NB Setup

# %%
# !pip install langdetect
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langdetect in /home/jupyter-svanhemert00/.local/lib/python3.9/site-packages (1.0.9)
# Requirement already satisfied: six in /opt/tljh/user/lib/python3.9/site-packages (from langdetect) (1.16.0)

# %%
# Import Libraries
import pandas as pd
import numpy as np
import re
from langdetect import detect

# %%
# Set display options to show all rows and columns
#pd.set_option('display.max_rows', None)  # Display all rows
#pd.set_option('display.max_columns', None)  # Display all columns
#pd.set_option('display.width', None)  # Auto-adjust width to display all columns

# Reset display options to default after printing
#pd.reset_option('display.max_rows')
#pd.reset_option('display.max_columns')
#pd.reset_option('display.width')

# %% [markdown]
# ## `df` Setup & Cleaning

# %%
# Read df
df = pd.read_csv('all_reviews_merged_3000_sample.csv')
df_copy = df.copy()
df.head(1)
# Out:
#          reviewId        asin date_cleaned      username            title  \
# 0  R2MESKRWXZPAPR  B08SRSWFY6   2021-07-02  Mettea Green  Good for drinks
#
#               keyword  verified  rating_cleaned  \
# 0  best Kids and Baby      True             4.0
#
#                                                 text train_test  \
# 0  Bought these in hopes to decrease buying apple...       test
#
#    sustainability (y/n)
# 0                     0

# %%
# Remove columns 'train_test' and 'sustainability (y/n)'
columns_to_drop = ['train_test', 'sustainability (y/n)']
df = df.drop(columns=columns_to_drop)
df.head(1)
# Out:
#          reviewId        asin date_cleaned      username            title  \
# 0  R2MESKRWXZPAPR  B08SRSWFY6   2021-07-02  Mettea Green  Good for drinks
#
#               keyword  verified  rating_cleaned  \
# 0  best Kids and Baby      True             4.0
#
#                                                 text
# 0  Bought these in hopes to decrease buying apple...

# %%
# Function to clean and filter reviews
def clean_review(review):
    # Remove leading and trailing whitespaces
    cleaned_text = review.strip()
    
    # Normalize whitespace to single spaces
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    
    # Sentence case: First character of the first word to uppercase, rest to lowercase
    cleaned_text = cleaned_text.capitalize()
    
    # Remove emojis and special characters
    cleaned_text = re.sub(r'[^\w\s]', '', cleaned_text)
    
    return cleaned_text

# %%
# Apply cleaning function to 'text' column
df['cleaned_text'] = df['text'].apply(clean_review)

# %%
# Function to detect English reviews
def is_english(text):
    try:
        lang = detect(text)
        return lang == 'en'
    except:
        return False

# Filter out non-English reviews
df = df[df['cleaned_text'].apply(is_english)]

# %%
# Compare df before and after cleaning
print(df_copy.shape)
print(df.shape)
# Out:
# (3000, 11)
# (2780, 10)

# %% [markdown]
# # ESGBERT
# NLP for Sustainable Finance and sister of https://huggingface.co/climatebert
#
# - HuggingFace Documentation: [ESGBERT Documentation](https://huggingface.co/ESGBERT)
# - Medium Tutorial: [Analyzing ESG with AI and NLP (Tutorial#1): Report Analysis Towards ESG Risks and Opportunities](https://medium.com/@schimanski.tobi/analyzing-esg-with-ai-and-nlp-tutorial-1-report-analysis-towards-esg-risks-and-opportunities-8daa2695f6c5_)

# %%
### MAKE SURE TO INSTALL THIS LIB: !pip install transformers
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline # for using the models

### Load the models (takes ca. 1 min)
# Environmental model.
name = "ESGBERT/EnvironmentalBERT-environmental" # path to download from HuggingFace
# In simple words, the tokenizer prepares the text for the model and the model classifies the text-
tokenizer = AutoTokenizer.from_pretrained(name)
model = AutoModelForSequenceClassification.from_pretrained(name)
# The pipeline combines tokenizer and model to one process.
pipe_env = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Also load the social and governance model.
# Social model.
name = "ESGBERT/SocialBERT-social"
tokenizer = AutoTokenizer.from_pretrained(name)
model = AutoModelForSequenceClassification.from_pretrained(name)
pipe_soc = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Governance model.
#name = "ESGBERT/GovernanceBERT-governance"
#tokenizer = AutoTokenizer.from_pretrained(name)
#model = AutoModelForSequenceClassification.from_pretrained(name)
#pipe_gov = pipeline("text-classification", model=model, tokenizer=tokenizer)
# Out:
# /home/jupyter-svanhemert00/.local/lib/python3.9/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()

# %% [markdown]
# ### Testing `ESGBERT/EnvironmentalBERT-environmental` and `ESGBERT/SocialBERT-social`

# %%
print(pipe_env("I like chocolate.", padding=True, truncation=True))
print(pipe_env("This product damages the environment.", padding=True, truncation=True))
print(pipe_env("The documentary had a strong focus on sustainability.", padding=True, truncation=True))
print(pipe_env("I don't like the way this product makes me feel.", padding=True, truncation=True))
print(pipe_env("The product is renewable and biodegradable.", padding=True, truncation=True))
# Out:
# [{'label': 'none', 'score': 0.9892128705978394}]
# [{'label': 'environmental', 'score': 0.9964158535003662}]
# [{'label': 'environmental', 'score': 0.9898588061332703}]
# [{'label': 'none', 'score': 0.9941224455833435}]
# [{'label': 'environmental', 'score': 0.9708414673805237}]

# %%
print(pipe_soc("This company behind the product is women and minority-owned.", padding=True, truncation=True))
print(pipe_soc("I like chocolate.", padding=True, truncation=True))
print(pipe_soc("The company does not care about its employees.", padding=True, truncation=True))
print(pipe_soc("Despite the reviews, this is not a good product.", padding=True, truncation=True))
print(pipe_soc("The company cares about social issues.", padding=True, truncation=True))
# Out:
# [{'label': 'social', 'score': 0.9997933506965637}]
# [{'label': 'none', 'score': 0.9996131062507629}]
# [{'label': 'social', 'score': 0.9997789263725281}]
# [{'label': 'none', 'score': 0.9999130964279175}]
# [{'label': 'social', 'score': 0.999315619468689}]

# %% [markdown]
# ## `ESGBERT/EnvironmentalBERT-environmental` - Application
# - Documentation: [EnvironmentalBERT-environmental](https://huggingface.co/ESGBERT/EnvironmentalBERT-environmental)

# %%
# Function to process environmental predictions
def env_process_predictions(predictions):
    for prediction in predictions:
        if prediction['label'] == 'none':
            return -prediction['score']  # Return negative score if label is 'none'
        elif prediction['label'] == 'environmental':
            return prediction['score']  # Return positive score if label is 'environmental'
        else:
            return np.nan  # Handle unexpected labels

# %%
# Apply pipe_env to each row in 'text' column
df['EnvironmentalBERT-environmental'] = df['cleaned_text'].apply(lambda x: pipe_env(x, padding=True, truncation=True))

# Process predictions and store as floats in new column
df['EnvironmentalBERT-environmental'] = df['EnvironmentalBERT-environmental'].apply(env_process_predictions)

# %%
# Filter rows where 'EnvironmentalBERT-environmental' > 0
df[df['EnvironmentalBERT-environmental'] > 0][['cleaned_text', 'EnvironmentalBERT-environmental']]
# Out:
#                                            cleaned_text  \
# 76    I gathered a lot of insight from watching this...
# 91    These bags go to landfill they are not compost...
# 189   Great product from fossil delivery was sharp g...
# 201   Great gift for little boys with lots of energy...
# 210   I liked the movie better than i thought it mus...
# 219   If youre not putting this under a roof then be...
# 220   Maybe its my fault for not realizing these are...
# 251   Wonderful depiction of history and the struggl...
# 455   4 of solar light motion are not detecting i di...
# 502   Very unique feel and softness to it by far the...
# 567   I bought this tiller to help make some flowerv...
# 664   I am a huge fan we needed a quick solution to ...
# 688   The camea is essentially useless it is a total...
# 797   Havent had to experience water resistance it i...
# 877   Got it for my husband in nov 2016 its working ...
# 977   Works good hd picture quality good speaker and...
# 1011  I love this hat great sun protection high qual...
# 1022  The battery has to be recharged every day and ...
# 1045  I have 2 of these cameras easy to setup solar ...
# 1046                              Cuter than i expected
# 1074  The shoes fit great but the lichen greenwaters...
# 1116  Great picture on this camera no issues with th...
# 1147  This product has helped me to have more energy...
# 1255  Ive been using this for months now and its bee...
# 1338  Large fit my 11 year old perfect she has a ver...
# 1361  Garbage im a kid of the 80s and the lite brigh...
# 1420  I got thses for a puppy and i love them holds ...
# 1435  I couldnt be happier with the sensi if you hav...
# 1506  Powers ring wall light solar with continuous p...
# 1564  These have helped my fur babies so much one of...
# 1643   One floodlight does not work i need to return it
# 1848  I rate this 5 stars but i did see something in...
# 1952  On one occasion my aunt bought this eco smart ...
# 1966  I loved this book it was wellwritten and capti...
# 2066  I have to drink mineral water for leg cramps a...
# 2080  I compared this to solar lights i bought at ho...
# 2151  I bought this for my mom on mothers day she is...
# 2286  These are great for accenting our trees and la...
# 2340  The deodorant doesnt last long id apply at abo...
# 2410  Poetic dramatic heart warming skillfully put t...
# 2503  Waste of money used it to water my garden leak...
# 2554  This is a truly great hat wide brim provides p...
# 2597  No bands exist larger than the large size whic...
# 2635  Very nice watch have no idea if its water proo...
# 2636  I just got the bag and only used it once it ke...
# 2714  Lights started flickering and now one one side...
# 2769  The combination of the great depression and a ...
#
#       EnvironmentalBERT-environmental
# 76                           0.765215
# 91                           0.919020
# 189                          0.995022
# 201                          0.756844
# 210                          0.934367
# 219                          0.849106
# 220                          0.582875
# 251                          0.717814
# 455                          0.904172
# 502                          0.564345
# 567                          0.602707
# 664                          0.919248
# 688                          0.580459
# 797                          0.598222
# 877                          0.786861
# 977                          0.577101
# 1011                         0.802016
# 1022                         0.992862
# 1045                         0.746189
# 1046                         0.918071
# 1074                         0.638156
# 1116                         0.779594
# 1147                         0.628178
# 1255                         0.833938
# 1338                         0.594775
# 1361                         0.897982
# 1420                         0.570297
# 1435                         0.558586
# 1506                         0.541021
# 1564                         0.534312
# 1643                         0.828856
# 1848                         0.802450
# 1952                         0.976529
# 1966                         0.711720
# 2066                         0.526217
# 2080                         0.863334
# 2151                         0.854081
# 2286                         0.877986
# 2340                         0.868098
# 2410                         0.856034
# 2503                         0.805976
# 2554                         0.527693
# 2597                         0.682367
# 2635                         0.548349
# 2636                         0.663764
# 2714                         0.834227
# 2769                         0.525572

# %% [markdown]
# ## `ESGBERT/SocialBERT-social` - Application
# - Documentation: [ESGBERT/SocialBERT-social](https://huggingface.co/ESGBERT/SocialBERT-social)

# %%
# Function to process social predictions
def soc_process_predictions(predictions):
    for prediction in predictions:
        if prediction['label'] == 'none':
            return -prediction['score']  # Return negative score if label is 'none'
        elif prediction['label'] == 'social':
            return prediction['score']  # Return positive score if label is 'environmental'
        else:
            return np.nan  # Handle unexpected labels

# %%
# Apply pipe_env to each row in 'text' column
df['ESGBERT/SocialBERT-social'] = df['cleaned_text'].apply(lambda x: pipe_soc(x, padding=True, truncation=True))

# Process predictions and store as floats in new column
df['ESGBERT/SocialBERT-social'] = df['ESGBERT/SocialBERT-social'].apply(soc_process_predictions)

# %%
# Filter rows where 'EnvironmentalBERT-environmental' > 0
df[df['ESGBERT/SocialBERT-social'] < 0][['cleaned_text', 'ESGBERT/SocialBERT-social']]
# Out:
#                                            cleaned_text  \
# 0     Bought these in hopes to decrease buying apple...
# 1     I bought vivoactive 3 to replace my polar i ha...
# 2     Ive had this less then a month and the pump ha...
# 3                       Bought these and theyre perfect
# 4     I had to return my first one because i got a d...
# ...                                                 ...
# 2995  My daughter and nieces loved this item they co...
# 2996  This item is something i did not order i order...
# 2997  So i bought this season back in november 2020 ...
# 2998             Great for small areas and small people
# 2999  These shoes are real cheap20 is tooo much for ...
#
#       ESGBERT/SocialBERT-social
# 0                     -0.999913
# 1                     -0.999816
# 2                     -0.999931
# 3                     -0.999904
# 4                     -0.999916
# ...                         ...
# 2995                  -0.999925
# 2996                  -0.999908
# 2997                  -0.999878
# 2998                  -0.997623
# 2999                  -0.999929
#
# [2748 rows x 2 columns]

# %% [markdown]
# ## Output Dataframe

# %%
df
# Out:
#             reviewId        asin date_cleaned          username  \
# 0     R2MESKRWXZPAPR  B08SRSWFY6   2021-07-02      Mettea Green
# 1      RP965NGI0QV7C  B074KBWL9J   2018-02-04               Ron
# 2     R1X00I45L1PM0X  B07H57NBGP   2021-12-18            Ashley
# 3      R739IV9ESOX5V  B071ZNFVMD   2020-03-29          superdad
# 4     R24NZ6FVQUABIO  B079775ZZQ   2020-09-19            Jordan
# ...              ...         ...          ...               ...
# 2995   RA1JXJK9B4FLF  B08FKZWPGH   2022-01-17    Leslie Edwards
# 2996  R1BMQ5M6JJQXQA  B006W6YHHI   2018-04-04   Thomas Bernardo
# 2997  R1LBAT6WY0NZW4  B074RKHNV6   2021-04-27   Amazon Customer
# 2998  R38V9NOYK59YBP  B0765VTBLV   2019-08-27  Anthony Lombardo
# 2999  R1KEOSBCHHTFRV  B07YS3QYQW   2020-06-03   Amazon Customer
#
#                                                   title  \
# 0                                       Good for drinks
# 1      I bought Vivoactive 3 to replace my Polar. I ...
# 2                                  Broke Within a Month
# 3                                  Great bags for the $
# 4                                          Works great!
# ...                                                 ...
# 2995                                        Great Gift!
# 2996      This item is something I did not order, I ...
# 2997                                                NaN
# 2998                               Very easy to install
# 2999  THESE SHOES ARE REALLY CHEAP...NOT WORTH THE M...
#
#                     keyword  verified  rating_cleaned  \
# 0        best Kids and Baby      True             4.0
# 1                     Watch     False             2.0
# 2         best Pet supplies      True             1.0
# 3     best Food and Grocery      True             4.0
# 4           best Smart home      True             4.0
# ...                     ...       ...             ...
# 2995                   Toys      True             5.0
# 2996           Pet supplies      True             1.0
# 2997                   Game      True             3.0
# 2998           best Outdoor      True             5.0
# 2999                  Shoes      True             1.0
#
#                                                    text  \
# 0     Bought these in hopes to decrease buying apple...
# 1     I bought Vivoactive 3 to replace my Polar. I h...
# 2     I’ve had this less then a month and the pump h...
# 3                     Bought these and they're perfect!
# 4     I had to return my first one because I got a d...
# ...                                                 ...
# 2995  My daughter and nieces loved this item. They c...
# 2996  This item is something I did not order, I orde...
# 2997  So I bought this season back in November 2020 ...
# 2998            Great for small areas and small people.
# 2999  THESE SHOES ARE REAL CHEAP...$20 IS TOOO MUCH ...
#
#                                            cleaned_text  \
# 0     Bought these in hopes to decrease buying apple...
# 1     I bought vivoactive 3 to replace my polar i ha...
# 2     Ive had this less then a month and the pump ha...
# 3                       Bought these and theyre perfect
# 4     I had to return my first one because i got a d...
# ...                                                 ...
# 2995  My daughter and nieces loved this item they co...
# 2996  This item is something i did not order i order...
# 2997  So i bought this season back in november 2020 ...
# 2998             Great for small areas and small people
# 2999  These shoes are real cheap20 is tooo much for ...
#
#       EnvironmentalBERT-environmental  ESGBERT/SocialBERT-social
# 0                           -0.992591                  -0.999913
# 1                           -0.992330                  -0.999816
# 2                           -0.995453                  -0.999931
# 3                           -0.991564                  -0.999904
# 4                           -0.995013                  -0.999916
# ...                               ...                        ...
# 2995                        -0.995071                  -0.999925
# 2996                        -0.995402                  -0.999908
# 2997                        -0.993736                  -0.999878
# 2998                        -0.992423                  -0.997623
# 2999                        -0.990740                  -0.999929
#
# [2780 rows x 12 columns]

# %%
# Save dataset
df.to_csv('ESGBERT_all_reviews_merged_3000_sample.csv', index=False)
print('Saved as CSV.')
# Out:
# Saved as CSV.
